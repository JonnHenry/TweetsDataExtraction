# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ### Arauz unión de datos

# %%
df_last_arauz = pd.read_csv("Twitter_search_Arauz.csv") 
df_last_arauz.head(5)
df_last_arauz['created_at'] = pd.to_datetime(df_last_arauz['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_last_arauz = df_last_arauz[df_last_arauz['created_at']<=time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 01 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_last_arauz.head(5)
# Out:
#               created_at  favorite_count  \
# 2559 2021-02-01 00:00:00               1
# 2560 2021-01-31 23:59:54               0
# 2561 2021-01-31 23:59:53               0
# 2562 2021-01-31 23:59:48               0
# 2563 2021-01-31 23:59:30               0
#
#                                               full_text               id_str  \
# 2559  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 2560  RT @carlosrojasecu: El candidato Andrés Arauz ...  1356029470554128384
# 2561  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029467274194946
# 2562  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029444817776641
# 2563  RT @ecuadorenvivo: #ELN habría prestado $80.00...  1356029369324593155
#
#      metadata.iso_language_code     retweeted_status.created_at  \
# 2559                         es                             NaN
# 2560                         es  Sun Jan 31 15:51:12 +0000 2021
# ...

# %%
df_new_arauz = pd.read_csv("Twitter_search_Arauz_new.csv") 
df_new_arauz['created_at'] = pd.to_datetime(df_new_arauz['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_new_arauz = df_new_arauz[df_new_arauz['created_at']>time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 01 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_new_arauz = df_new_arauz[df_new_arauz['created_at']<time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Sun Feb 07 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_new_arauz.head(5)
# Out:
#                created_at  favorite_count  \
# 12592 2021-02-06 23:59:56               0
# 12593 2021-02-06 23:59:46               0
# 12594 2021-02-06 23:59:43               0
# 12595 2021-02-06 23:59:41               0
# 12596 2021-02-06 23:59:33               0
#
#                                                full_text               id_str  \
# 12592  RT @Heryjesus4f: Lenin Moreno traicionó al pue...  1358203805444132864
# 12593  RT @liliamm_27: Para que ECUADOR avance, debe ...  1358203765531291650
# 12594  RT @tioelmoi: Yo nadando en las lágrimas de lo...  1358203751350362115
# 12595  RT @brozoxmiswebs: El candidato a la presidenc...  1358203742873677824
# 12596  RT @jmkarg: Andrés Arauz cerró su campaña pres...  1358203710728470528
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 12592                         es  Sat Feb 06 18:38:49 +0000 2021
# 12593                         es  Sat Feb 06 21:06:40 +0000 2021
# ...

# %%
data_tweets_arauz = pd.concat([df_last_arauz, df_new_arauz], axis=0)
data_tweets_arauz = data_tweets_arauz.reset_index(drop=True)
data_tweets_arauz.head(5)
# Out:
#            created_at  favorite_count  \
# 0 2021-02-01 00:00:00               1
# 1 2021-01-31 23:59:54               0
# 2 2021-01-31 23:59:53               0
# 3 2021-01-31 23:59:48               0
# 4 2021-01-31 23:59:30               0
#
#                                            full_text               id_str  \
# 0  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 1  RT @carlosrojasecu: El candidato Andrés Arauz ...  1356029470554128384
# 2  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029467274194946
# 3  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029444817776641
# 4  RT @ecuadorenvivo: #ELN habría prestado $80.00...  1356029369324593155
#
#   metadata.iso_language_code     retweeted_status.created_at  \
# 0                         es                             NaN
# 1                         es  Sun Jan 31 15:51:12 +0000 2021
# 2                         es  Sun Jan 31 19:20:13 +0000 2021
# ...

# %%
data_tweets_arauz.to_csv("all_tweets_arauz.csv",index=False)

# %%
len(data_tweets_arauz)
# Out:
# 120747

# %% [markdown]
# ### Lasso unión de datos

# %%
df_last_lasso = pd.read_csv("Twitter_search_Lasso.csv") 
df_last_lasso['created_at'] = pd.to_datetime(df_last_lasso['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_last_lasso = df_last_lasso[df_last_lasso['created_at']<=time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 01 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_last_lasso.head(5)
# Out:
#               created_at  favorite_count  \
# 2254 2021-02-01 00:00:00               1
# 2255 2021-01-31 23:59:47               0
# 2256 2021-01-31 23:59:30               0
# 2257 2021-01-31 23:59:22               0
# 2258 2021-01-31 23:59:19               0
#
#                                               full_text               id_str  \
# 2254  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 2255  RT @karitupl_: Y si van a venir con lo del Fer...  1356029442645233665
# 2256  RT @relicheandres: Guillermo Lasso es una cart...  1356029372596154381
# 2257  RT @fabriciovelav: AHORA: @ECUATRANSA despidió...  1356029337548558337
# 2258  RT @farriancito: Guillermo Lasso:\n'Gracias Da...  1356029324969836544
#
#      metadata.iso_language_code     retweeted_status.created_at  \
# 2254                         es                             NaN
# 2255                         es  Sun Jan 31 22:19:16 +0000 2021
# ...

# %%
df_new_lasso = pd.read_csv("Twitter_search_Lasso_new.csv") 
df_new_lasso['created_at'] = pd.to_datetime(df_new_lasso['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_new_lasso = df_new_lasso[df_new_lasso['created_at']>time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 01 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_new_lasso = df_new_lasso[df_new_lasso['created_at']<time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Sun Feb 07 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_new_lasso.head(5)
# Out:
#               created_at  favorite_count  \
# 4274 2021-02-06 23:59:52               0
# 4275 2021-02-06 23:59:50               5
# 4276 2021-02-06 23:59:14               0
# 4277 2021-02-06 23:59:13               0
# 4278 2021-02-06 23:58:23               0
#
#                                               full_text               id_str  \
# 4274  RT @yanine_torres: Ya me decidí mi voto va par...  1358203791598878734
# 4275  @LoroHomero lacayo de Guillermo Lasso y María ...  1358203781360594946
# 4276  RT @MarcoAnibal: @BernardOrellana ¿Es en serio...  1358203631581954048
# 4277  RT @PatricioMery: Queda claro que votar por He...  1358203627421237249
# 4278  RT @Danielsalcan88: Como Don Alfonso no trabaj...  1358203418268078080
#
#      metadata.iso_language_code     retweeted_status.created_at  \
# 4274                         es  Sat Feb 06 14:15:38 +0000 2021
# 4275                         es                             NaN
# ...

# %%
data_tweets_lasso = pd.concat([df_last_lasso, df_new_lasso], axis=0)
data_tweets_lasso = data_tweets_lasso.reset_index(drop=True)
data_tweets_lasso.head(5)
# Out:
#            created_at  favorite_count  \
# 0 2021-02-01 00:00:00               1
# 1 2021-01-31 23:59:47               0
# 2 2021-01-31 23:59:30               0
# 3 2021-01-31 23:59:22               0
# 4 2021-01-31 23:59:19               0
#
#                                            full_text               id_str  \
# 0  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 1  RT @karitupl_: Y si van a venir con lo del Fer...  1356029442645233665
# 2  RT @relicheandres: Guillermo Lasso es una cart...  1356029372596154381
# 3  RT @fabriciovelav: AHORA: @ECUATRANSA despidió...  1356029337548558337
# 4  RT @farriancito: Guillermo Lasso:\n'Gracias Da...  1356029324969836544
#
#   metadata.iso_language_code     retweeted_status.created_at  \
# 0                         es                             NaN
# 1                         es  Sun Jan 31 22:19:16 +0000 2021
# 2                         es  Sun Jan 31 18:45:05 +0000 2021
# ...

# %%
data_tweets_lasso.to_csv("all_tweets_lasso.csv",index=False)

# %%
len(data_tweets_lasso)
# Out:
# 50781

# %% [markdown]
# #### After Arauz data

# %%
df_after_arauz = pd.read_csv("tweets_arauz_after_elections.csv") 
df_after_arauz['created_at'] = pd.to_datetime(df_after_arauz['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_after_arauz = df_after_arauz[df_after_arauz['created_at']<time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Sun Feb 14 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_after_arauz = df_after_arauz[df_after_arauz['created_at']>time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 08 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]

df_after_arauz.head(5)
# Out:
#                created_at  favorite_count  \
# 17059 2021-02-13 23:59:56               0
# 17060 2021-02-13 23:59:56               0
# 17061 2021-02-13 23:59:53               0
# 17062 2021-02-13 23:59:53               2
# 17063 2021-02-13 23:59:52               0
#
#                                                full_text               id_str  \
# 17059  RT @PatricioMery: El escenario ideal para el E...  1360740523892473859
# 17060  RT @OrlenysOV: Semejante maniobra colectiva ne...  1360740520520282112
# 17061  RT @farriancito: Andres Venegas Londoño, alias...  1360740510890160129
# 17062  @tioelmoi Diana Salazar no debias meterte a tr...  1360740510298734592
# 17063  RT @VickyDavilaH: SEMANA: Samper está furioso ...  1360740507043966979
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 17059                         es  Sat Feb 13 18:50:33 +0000 2021
# 17060                         es  Sat Feb 13 01:50:38 +0000 2021
# ...

# %%
df_after_arauz.tail(5)
# Out:
#                created_at  favorite_count  \
# 98627 2021-02-08 00:00:04               0
# 98628 2021-02-08 00:00:03               0
# 98629 2021-02-08 00:00:03               0
# 98630 2021-02-08 00:00:01               0
# 98631 2021-02-08 00:00:01               0
#
#                                                full_text               id_str  \
# 98627  RT @CarlosP05340289: - Andrés Arauz :  Abuelit...  1358566226742693889
# 98628  RT @JuanCar29935646: El pueblo se respeta: el ...  1358566225387937792
# 98629  RT @eldestapeweb: El correísta Andrés Arauz se...  1358566224909713414
# 98630  RT @GustavoBolivar: Hoy Ecuador, luego de la t...  1358566217297113090
# 98631  RT @romerodiario: PALPITO: Más de 40 pts y más...  1358566216701513731
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 98627                         es  Sun Feb 07 21:16:17 +0000 2021
# 98628                         es  Sun Feb 07 23:32:06 +0000 2021
# ...

# %%
df_after_arauz.to_csv('tweets_after_arauz.csv',index=False)

# %%
len(df_after_arauz)
# Out:
# 81573

# %% [markdown]
# #### After Lasso data

# %%
df_after_lasso = pd.read_csv("tweets_lasso_after_elections.csv") 
df_after_lasso['created_at'] = pd.to_datetime(df_after_lasso['created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
df_after_lasso = df_after_lasso[df_after_lasso['created_at']<time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Sun Feb 14 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_after_lasso = df_after_lasso[df_after_lasso['created_at']>time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 08 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]

df_after_lasso.head(5)
# Out:
#               created_at  favorite_count  \
# 2690 2021-02-13 23:59:22               1
# 2691 2021-02-13 23:59:12               0
# 2692 2021-02-13 23:58:41               0
# 2693 2021-02-13 23:57:49               0
# 2694 2021-02-13 23:57:13               0
#
#                                               full_text               id_str  \
# 2690  @AleSanchez25 @LassoGuillermo Muchas gracias, ...  1360740379847499780
# 2691  RT @Guayaco__2020: - Andrés Arauz: 3'027.073\n...  1360740336100868097
# 2692  RT @MarcoAnibal: Escuchar a Carlos Pérez Guart...  1360740207184732162
# 2693  RT @CarlosP05340289: Guillermo Lasso con su tí...  1360739987927543813
# 2694  RT @Datoworld: 🇪🇨#Ecuador-Segunda Vuelta \n\n🔵...  1360739839604367362
#
#      metadata.iso_language_code     retweeted_status.created_at  \
# 2690                         es                             NaN
# 2691                         es  Sat Feb 13 00:38:10 +0000 2021
# ...

# %%
df_after_lasso.tail(5)
# Out:
#                created_at  favorite_count  \
# 75973 2021-02-08 00:00:14               0
# 75974 2021-02-08 00:00:11               0
# 75975 2021-02-08 00:00:06               0
# 75976 2021-02-08 00:00:04               0
# 75977 2021-02-08 00:00:02               0
#
#                                                full_text               id_str  \
# 75973  RT @nandozea_: ¿Qué se necesita para ganar en ...  1358566270837399552
# 75974  RT @ElEstadoNet: Exit Poll de Elecciones Presi...  1358566259160449025
# 75975  RT @amoralesan: El candidato de izquierda ecua...  1358566235953369093
# 75976  RT @CarlosP05340289: - Andrés Arauz :  Abuelit...  1358566226742693889
# 75977  RT @InfoNodal: #NODALTemas - #Ecuador 🇪🇨, prim...  1358566221084459008
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 75973                         es  Sun Feb 07 23:59:45 +0000 2021
# 75974                         es  Sun Feb 07 19:56:30 +0000 2021
# ...

# %%
df_after_lasso.to_csv('tweets_after_lasso.csv',index=False)

# %% [markdown]
# # Join All Data

# %% [markdown]
# ### Arauz

# %%
df_before_arauz = pd.read_csv("all_tweets_arauz.csv")
df_after_arauz = pd.read_csv("tweets_after_arauz.csv")

# %%
df_before_arauz.tail(5)
# Out:
#                  created_at  favorite_count  \
# 120742  2021-02-01 00:01:08               0
# 120743  2021-02-01 00:00:44               0
# 120744  2021-02-01 00:00:23               0
# 120745  2021-02-01 00:00:21               0
# 120746  2021-02-01 00:00:06               6
#
#                                                 full_text  \
# 120742  RT @politikcorrecta: El candidato por @cendemo...
# 120743  RT @CarlosP05340289: Pelearse con tus amigos p...
# 120744  RT @ErmelRosario: 🇪🇨POR MI LINDO ECUADOR, SOLO...
# 120745  RT @petrogustavo: Intentan por todos los medio...
# 120746  @larryyumibandam @MashiRafael @La6Ecuador @Las...
#
#                      id_str metadata.iso_language_code  \
# 120742  1356029780018294787                         es
# 120743  1356029680277741571                         es
# 120744  1356029594864934916                         es
# 120745  1356029583942971395                         es
# 120746  1356029522987118592                         es
#
# ...

# %%
data_tweets_arauz = pd.concat([df_before_arauz, df_after_arauz], axis=0)
data_tweets_arauz = data_tweets_arauz.reset_index(drop=True)
data_tweets_arauz.head(5)
# Out:
#             created_at  favorite_count  \
# 0  2021-02-01 00:00:00               1
# 1  2021-01-31 23:59:54               0
# 2  2021-01-31 23:59:53               0
# 3  2021-01-31 23:59:48               0
# 4  2021-01-31 23:59:30               0
#
#                                            full_text               id_str  \
# 0  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 1  RT @carlosrojasecu: El candidato Andrés Arauz ...  1356029470554128384
# 2  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029467274194946
# 3  RT @VTVcanal8: Candidato del Correísmo, Andrés...  1356029444817776641
# 4  RT @ecuadorenvivo: #ELN habría prestado $80.00...  1356029369324593155
#
#   metadata.iso_language_code     retweeted_status.created_at  \
# 0                         es                             NaN
# 1                         es  Sun Jan 31 15:51:12 +0000 2021
# 2                         es  Sun Jan 31 19:20:13 +0000 2021
# ...

# %%
data_tweets_arauz = data_tweets_arauz.sort_values('created_at')

# %%
data_tweets_arauz.tail(5)
# Out:
#                  created_at  favorite_count  \
# 120751  2021-02-13 23:59:52               0
# 120750  2021-02-13 23:59:53               2
# 120749  2021-02-13 23:59:53               0
# 120747  2021-02-13 23:59:56               0
# 120748  2021-02-13 23:59:56               0
#
#                                                 full_text  \
# 120751  RT @VickyDavilaH: SEMANA: Samper está furioso ...
# 120750  @tioelmoi Diana Salazar no debias meterte a tr...
# 120749  RT @farriancito: Andres Venegas Londoño, alias...
# 120747  RT @PatricioMery: El escenario ideal para el E...
# 120748  RT @OrlenysOV: Semejante maniobra colectiva ne...
#
#                      id_str metadata.iso_language_code  \
# 120751  1360740507043966979                         es
# 120750  1360740510298734592                         es
# 120749  1360740510890160129                         es
# 120747  1360740523892473859                         es
# 120748  1360740520520282112                         es
#
# ...

# %%
data_tweets_arauz.head(5)
# Out:
#                 created_at  favorite_count  \
# 53355  2021-01-24 11:09:43               0
# 53354  2021-01-24 11:11:10               0
# 53353  2021-01-24 11:11:47               0
# 53352  2021-01-24 11:12:50               0
# 53351  2021-01-24 11:14:35               0
#
#                                                full_text               id_str  \
# 53355  RT @CarlosP05340289: El LELO Andrés Arauz nos ...  1353298931913019393
# 53354  RT @sybelmartinez: A qué edad se enteraron que...  1353299298407096320
# 53353  RT @veronicaariasf: Con una extraordinaria car...  1353299454103838720
# 53352  RT @kolectiVOZ: David Villamar: "Los #MilDeUna...  1353299717485158400
# 53351  RT @PrensaDelBanano: Andrés Arauz fue el ganad...  1353300160277852160
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 53355                         es  Sat Jan 23 22:05:45 +0000 2021
# 53354                         es  Sat Jan 23 23:38:46 +0000 2021
# ...

# %%
data_tweets_arauz.to_csv('tweets_arauz.csv',index=False)

# %%
len(data_tweets_arauz)
# Out:
# 202320

# %% [markdown]
# ## Lasso

# %%
df_before_lasso = pd.read_csv("all_tweets_lasso.csv")
df_after_lasso = pd.read_csv("tweets_after_lasso.csv")

# %%
data_tweets_lasso = pd.concat([df_before_lasso, df_after_lasso], axis=0)
data_tweets_lasso = data_tweets_lasso.reset_index(drop=True)
data_tweets_lasso.head(5)
# Out:
#             created_at  favorite_count  \
# 0  2021-02-01 00:00:00               1
# 1  2021-01-31 23:59:47               0
# 2  2021-01-31 23:59:30               0
# 3  2021-01-31 23:59:22               0
# 4  2021-01-31 23:59:19               0
#
#                                            full_text               id_str  \
# 0  #Elecciones2021Ec | ¿Las propuestas económicas...  1356029498307784705
# 1  RT @karitupl_: Y si van a venir con lo del Fer...  1356029442645233665
# 2  RT @relicheandres: Guillermo Lasso es una cart...  1356029372596154381
# 3  RT @fabriciovelav: AHORA: @ECUATRANSA despidió...  1356029337548558337
# 4  RT @farriancito: Guillermo Lasso:\n'Gracias Da...  1356029324969836544
#
#   metadata.iso_language_code     retweeted_status.created_at  \
# 0                         es                             NaN
# 1                         es  Sun Jan 31 22:19:16 +0000 2021
# 2                         es  Sun Jan 31 18:45:05 +0000 2021
# ...

# %%
data_tweets_lasso = data_tweets_lasso.sort_values('created_at')
data_tweets_lasso.tail(2)
# Out:
#                 created_at  favorite_count  \
# 50782  2021-02-13 23:59:12               0
# 50781  2021-02-13 23:59:22               1
#
#                                                full_text               id_str  \
# 50782  RT @Guayaco__2020: - Andrés Arauz: 3'027.073\n...  1360740336100868097
# 50781  @AleSanchez25 @LassoGuillermo Muchas gracias, ...  1360740379847499780
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 50782                         es  Sat Feb 13 00:38:10 +0000 2021
# 50781                         es                             NaN
#
#                               retweeted_status.full_text  \
# 50782  - Andrés Arauz: 3'027.073\n- Guillermo Lasso: ...
# 50781                                                NaN
#
#                       user.created_at  user.favourites_count  \
# 50782  Sun Nov 21 21:48:17 +0000 2010                  67236
# 50781  Tue Mar 08 01:40:40 +0000 2011                   1608
#
# ...

# %%
data_tweets_lasso.head(2)
# Out:
#                 created_at  favorite_count  \
# 24862  2021-01-24 18:48:13               0
# 24861  2021-01-24 18:50:06               0
#
#                                                full_text               id_str  \
# 24862  RT @Danielsalcan88: Se imaginan un gobierno de...  1353414316947550213
# 24861  RT @DiegoFuentesEC: Lenín Moreno NO gobernó co...  1353414791684042757
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 24862                         es  Sat Jan 23 23:24:31 +0000 2021
# 24861                         es  Mon Jan 18 22:50:08 +0000 2021
#
#                               retweeted_status.full_text  \
# 24862  Se imaginan un gobierno de Guillermo Lasso con...
# 24861  Lenín Moreno NO gobernó con Alianza PAIS, lo h...
#
#                       user.created_at  user.favourites_count  \
# 24862  Sun Jan 05 21:38:08 +0000 2020                  22225
# 24861  Tue Oct 23 14:39:27 +0000 2018                   3027
#
# ...

# %%
data_tweets_lasso.to_csv('tweets_lasso.csv',index=False)

# %%
len(data_tweets_lasso)
# Out:
# 124069

# %%
df_prueba = data_tweets_lasso[data_tweets_lasso['created_at']>time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Sun Feb 07 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_prueba = df_prueba[df_prueba['created_at']<time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Mon Feb 08 00:00:00 +0000 2021','%a %b %d %H:%M:%S +0000 %Y'))]
df_prueba
# Out:
# Empty DataFrame
# Columns: [created_at, favorite_count, full_text, id_str, metadata.iso_language_code, retweeted_status.created_at, retweeted_status.full_text, user.created_at, user.favourites_count, user.followers_count, user.friends_count, user.id_str, user.location, user.verified, retweet_count, Unnamed: 0]
# Index: []

# %%
df = pd.read_csv('tweets_arauz.csv')
df
# Out:
#                  created_at  favorite_count  \
# 0       2021-01-24 11:09:43               0
# 1       2021-01-24 11:11:10               0
# 2       2021-01-24 11:11:47               0
# 3       2021-01-24 11:12:50               0
# 4       2021-01-24 11:14:35               0
# ...                     ...             ...
# 202315  2021-02-13 23:59:52               0
# 202316  2021-02-13 23:59:53               2
# 202317  2021-02-13 23:59:53               0
# 202318  2021-02-13 23:59:56               0
# 202319  2021-02-13 23:59:56               0
#
#                                                 full_text  \
# 0       RT @CarlosP05340289: El LELO Andrés Arauz nos ...
# 1       RT @sybelmartinez: A qué edad se enteraron que...
# 2       RT @veronicaariasf: Con una extraordinaria car...
# 3       RT @kolectiVOZ: David Villamar: "Los #MilDeUna...
# 4       RT @PrensaDelBanano: Andrés Arauz fue el ganad...
# ...                                                   ...
# ...
